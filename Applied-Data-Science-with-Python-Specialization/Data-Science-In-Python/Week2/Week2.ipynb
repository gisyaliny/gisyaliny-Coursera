# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-Series-Data-Structure" data-toc-modified-id="The-Series-Data-Structure-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>The Series Data Structure</a></span></li><li><span><a href="#Querying-a-Series" data-toc-modified-id="Querying-a-Series-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Querying a Series</a></span></li><li><span><a href="#DataFrame-Data-Structure" data-toc-modified-id="DataFrame-Data-Structure-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>DataFrame Data Structure</a></span></li><li><span><a href="#DataFrame-Indexing-and-Loading" data-toc-modified-id="DataFrame-Indexing-and-Loading-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DataFrame Indexing and Loading</a></span></li><li><span><a href="#Querying-a-DataFrame" data-toc-modified-id="Querying-a-DataFrame-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Querying a DataFrame</a></span></li><li><span><a href="#Indexing-Dataframes" data-toc-modified-id="Indexing-Dataframes-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Indexing Dataframes</a></span><ul class="toc-item"><li><span><a href="#Census-file" data-toc-modified-id="Census-file-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Census file</a></span></li></ul></li><li><span><a href="#Missing-Values" data-toc-modified-id="Missing-Values-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Missing Values</a></span><ul class="toc-item"><li><span><a href="#df.fillna()" data-toc-modified-id="df.fillna()-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span><code>df.fillna()</code></a></span></li><li><span><a href="#Fill-the-missing-value" data-toc-modified-id="Fill-the-missing-value-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Fill the missing value</a></span></li><li><span><a href="#replace" data-toc-modified-id="replace-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span><code>replace</code></a></span></li></ul></li><li><span><a href="#Example:-Manipulating-DataFrame" data-toc-modified-id="Example:-Manipulating-DataFrame-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Example: Manipulating DataFrame</a></span></li></ul></div>

# %% [markdown]
# ## The Series Data Structure

# %%
import pandas as pd
students = ['Alice','Jack','Molly']
pd.Series(students)
# Out:
# 0    Alice
# 1     Jack
# 2    Molly
# dtype: object

# %%
numbers = [1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
students = ['Alice','Jack',None]
pd.Series(students)
# Out:
# 0    Alice
# 1     Jack
# 2     None
# dtype: object

# %%
numbers = [1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
# NaN and None not the same thing
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
studens_scores = {'Alice':'Physics',
                  'Jack': 'Chemistry',
                  'Molly': 'English'}
s = pd.Series(studens_scores)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
s.index
# Out:
# Index(['Alice', 'Jack', 'Molly'], dtype='object')

# %%
s = pd.Series(['Physics','Chemistry','English'],index=['Alice','Jack','Molly'])
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
studens_scores = {'Alice':'Physics',
                  'Jack': 'Chemistry',
                  'Molly': 'English'}
s = pd.Series(studens_scores,index=['Alice','Sam','Molly'])
s
# Out:
# Alice    Physics
# Sam          NaN
# Molly    English
# dtype: object

# %% [markdown]
# ## Querying a Series
# * `iloc`: query by location
# * `loc`: query by index label

# %%
studens_classes = {'Alice':'Physics',
                  'Jack': 'Chemistry',
                  'Molly': 'English',
                  'Sam':'History'}
s = pd.Series(studens_classes)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
s.iloc[3]
# Out:
# 'History'

# %%
s.loc['Molly']
# Out:
# 'English'

# %%
# not recommend
s[3]
# Out:
# 'History'

# %%
# not recommend
s['Molly']
# Out:
# 'English'

# %%
class_code = {99:'Physics',
             100:'Chemistry',
             101:'English',
             102:'History'}
s = pd.Series(class_code)
s
# Out:
# 99       Physics
# 100    Chemistry
# 101      English
# 102      History
# dtype: object

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-c9c96910e542> in <module>
# ----> 1 s[0]
#
# ...

# %%
s[99]
# Out:
# 'Physics'

# %%
grades = pd.Series([90,80,70,60])

total = 0
for grade in grades:
    total+=grade
print(total / len(grades))
# Out:
# 75.0

# %%
total = np.sum(grades)
print(total/len(grades))
# Out:
# 75.0

# %%
numbers = pd.Series(np.random.randint(0,10000,10000))
numbers.head()
# Out:
# 0    8363
# 1    3002
# 2    9348
# 3    1823
# 4    5896
# dtype: int32

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total+=number
total / len(numbers)
# Out:
# 895 µs ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total = np.sum(numbers)
total/len(numbers)
# Out:
# 49.3 µs ± 2.17 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
numbers +=2
numbers.head()
# Out:
# 0    8365
# 1    3004
# 2    9350
# 3    1825
# 4    5898
# dtype: int32

# %%
for label,value in numbers.iteritems():
    numbers.at[2,label] = value+2
numbers.head()
# Out:
# 0    8367
# 1    3006
# 2    3090
# 3    1827
# 4    5900
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label,value in s.iteritems():
    s.loc[label] = value + 2
# Out:
# 315 ms ± 1.37 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
s+=2
# Out:
# 233 µs ± 22.1 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
s = pd.Series([1,2,3])
s.loc['History'] = 102
s
# Out:
# 0            1
# 1            2
# 2            3
# History    102
# dtype: int64

# %%
studens_classes
studens_classes = pd.Series(studens_classes)
studens_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
kelly_classes = pd.Series(['Philosophy','Arts','Math'],index=['Kelly','Kelly','Kelly'])
kelly_classes
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
all_students_classes = studens_classes.append(kelly_classes)
all_students_classes
# Out:
# Alice       Physics
# Jack      Chemistry
# Molly       English
# Sam         History
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
all_students_classes.loc['Kelly']
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %% [markdown]
# ## DataFrame Data Structure

# %%
record1 = pd.Series({'Name': 'Alice',
                    'Class':'Physics',
                    'Score':85})
record2 = pd.Series({'Name': 'Jack',
                    'Class':'Chemistry',
                    'Score':82})
record3 = pd.Series({'Name': 'Helen',
                    'Class':'Biology',
                    'Score':90})

# %%
df = pd.DataFrame([record1,record2,record3],index=['school1','school2','school1'])
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
students = [
    {'Name': 'Alice',
                    'Class':'Physics',
                    'Score':85},
    {'Name': 'Jack',
                    'Class':'Chemistry',
                    'Score':82},
    {'Name': 'Helen',
                    'Class':'Biology',
                    'Score':90}    
]
df = pd.DataFrame(students,index=['school1','school2','school1'])
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
df.loc['school2']
# Out:
# Name          Jack
# Class    Chemistry
# Score           82
# Name: school2, dtype: object

# %%
type(df.loc['school2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['school1']
# Out:
#           Name    Class  Score
# school1  Alice  Physics     85
# school1  Helen  Biology     90

# %%
type(df.loc['school1'])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['school1','Name']
# Out:
# school1    Alice
# school1    Helen
# Name: Name, dtype: object

# %%
df.T
# Out:
#        school1    school2  school1
# Name     Alice       Jack    Helen
# Class  Physics  Chemistry  Biology
# Score       85         82       90

# %%
df.T.loc['Name']
# Out:
# school1    Alice
# school2     Jack
# school1    Helen
# Name: Name, dtype: object

# %%
df['Name']
# Out:
# school1    Alice
# school2     Jack
# school1    Helen
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc['school1']['Name']
# Out:
# school1    Alice
# school1    Helen
# Name: Name, dtype: object

# %%
df.loc[:,['Name','Score']]
# Out:
#           Name  Score
# school1  Alice     85
# school2   Jack     82
# school1  Helen     90

# %%
df.drop('school2')
# Out:
#           Name    Class  Score
# school1  Alice  Physics     85
# school1  Helen  Biology     90

# %%
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
copy_df = df.copy()

copy_df.drop("Name",inplace = True, axis = 1)
copy_df
# Out:
#              Class  Score
# school1    Physics     85
# school2  Chemistry     82
# school1    Biology     90

# %%
del copy_df['Class']
copy_df
# Out:
#          Score
# school1     85
# school2     82
# school1     90

# %%
df['ClassRanking'] = None
df
# Out:
#           Name      Class  Score ClassRanking
# school1  Alice    Physics     85         None
# school2   Jack  Chemistry     82         None
# school1  Helen    Biology     90         None

# %% [markdown]
# ## DataFrame Indexing and Loading

# %%
# !cat datasets/Admission_Predict.csv
# Out:
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit
# 1,337,118,4,4.5,4.5,9.65,1,0.92
# 2,324,107,4,4,4.5,8.87,1,0.76
# 3,316,104,3,3,3.5,8,1,0.72
# 4,322,110,3,3.5,2.5,8.67,1,0.8
# 5,314,103,2,2,3,8.21,0,0.65
# 6,330,115,5,4.5,3,9.34,1,0.9
# 7,321,109,3,3,4,8.2,1,0.75
# 8,308,101,2,3,4,7.9,0,0.68
# 9,302,102,1,2,1.5,8,0,0.5
# 10,323,108,3,3.5,3,8.6,0,0.45
# 11,325,106,3,3.5,4,8.4,1,0.52
# 12,327,111,4,4,4.5,9,1,0.84
# 13,328,112,4,4,4.5,9.1,1,0.78
# 14,307,109,3,4,3,8,1,0.62
# 15,311,104,3,3.5,2,8.2,1,0.61
# 16,314,105,3,3.5,2.5,8.3,0,0.54
# 17,317,107,3,4,3,8.7,0,0.66
# 18,319,106,3,4,3,8,1,0.65
# 19,318,110,3,4,3,8.8,0,0.63
# 20,303,102,3,3.5,3,8.5,0,0.62
# 21,312,107,3,3,2,7.9,1,0.64
# 22,325,114,4,3,2,8.4,0,0.7
# 23,328,116,5,5,5,9.5,1,0.94
# 24,334,119,5,5,4.5,9.7,1,0.95
# 25,336,119,5,4,3.5,9.8,1,0.97
# 26,340,120,5,4.5,4.5,9.6,1,0.94
# 27,322,109,5,4.5,3.5,8.8,0,0.76
# 28,298,98,2,1.5,2.5,7.5,1,0.44
# 29,295,93,1,2,2,7.2,0,0.46
# ...

# %%
df = pd.read_csv('datasets/Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df = pd.read_csv('datasets/Admission_Predict.csv',index_col=0)
df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 398               330          116                  4  5.0   4.5  9.45
# 399               312          103                  3  3.5   4.0  8.78
# 400               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
new_df = df.rename(columns={'GER Score':'GRE Score','TOEFL Score': 'TOEFL Score','University Rating': 'University Rating',
                           'SOP':'Statement of Purpose','LOR':'Letter of Recommendation'})

# %%
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = new_df.rename(mapper=str.strip,axis=1)
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR  CGPA  Research  Chance of Admit
# Serial No.
# 1           4.5  9.65         1             0.92
# 2           4.5  8.87         1             0.76
# 3           3.5  8.00         1             0.72
# 4           2.5  8.67         1             0.80
# 5           3.0  8.21         0             0.65

# %%
cols = list(df.columns)
cols =  [x.lower().strip() for x in cols]
df.columns = cols
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %% [markdown]
# ## Querying a DataFrame

# %%
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
admit_mask = df['chance of admit'] >0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
df[df['chance of admit'] > 0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df[['gre score','toefl score']].head()
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103

# %%
(df['chance of admit'] > 0.7) and (df['chance of admit'] <0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-8e8988411f56> in <module>
# ----> 1 (df['chance of admit'] > 0.7) and (df['chance of admit'] <0.9)
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
(df['chance of admit'] > 0.7) & (df['chance of admit'] <0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df['chance of admit'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df[(df['chance of admit'] > 0.7) & (df['chance of admit'] <0.9)].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 7                 321          109                  3  3.0  4.0  8.20
# 12                327          111                  4  4.0  4.5  9.00
#
#             research  chance of admit
# Serial No.
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 7                  1             0.75
# 12                 1             0.84

# %% [markdown]
# ## Indexing Dataframes

# %%
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
df['Serial Number'] = df.index
df = df.set_index('chance of admit')
df.head()
# Out:
#                  gre score  toefl score  university rating  sop  lor  cgpa  \
# chance of admit
# 0.92                   337          118                  4  4.5  4.5  9.65
# 0.76                   324          107                  4  4.0  4.5  8.87
# 0.72                   316          104                  3  3.0  3.5  8.00
# 0.80                   322          110                  3  3.5  2.5  8.67
# 0.65                   314          103                  2  2.0  3.0  8.21
#
#                  research  Serial Number
# chance of admit
# 0.92                    1              1
# 0.76                    1              2
# 0.72                    1              3
# 0.80                    1              4
# 0.65                    0              5

# %%
df.reset_index()
# Out:
#      chance of admit  gre score  toefl score  university rating  sop  lor  \
# 0               0.92        337          118                  4  4.5  4.5
# 1               0.76        324          107                  4  4.0  4.5
# 2               0.72        316          104                  3  3.0  3.5
# 3               0.80        322          110                  3  3.5  2.5
# 4               0.65        314          103                  2  2.0  3.0
# ..               ...        ...          ...                ...  ...  ...
# 395             0.82        324          110                  3  3.5  3.5
# 396             0.84        325          107                  3  3.0  3.5
# 397             0.91        330          116                  4  5.0  4.5
# 398             0.67        312          103                  3  3.5  4.0
# 399             0.95        333          117                  4  5.0  4.0
#
#      cgpa  research  Serial Number
# 0    9.65         1              1
# ...

# %% [markdown]
# ### Census file

# %%
df = pd.read_csv('datasets/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.SUMLEV.unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df_50 = df[df['SUMLEV']==50]
df_50.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df_50.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
columns_to_keep = ['STNAME', 'CTYNAME','BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014','BIRTHS2015']
df_50 = df_50[columns_to_keep]
df_50.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015
# 1         623         600
# 2        2186        2240
# 3         260         269
# 4         247         253
# 5         618         603

# %%
df_50 = df_50.set_index(['STNAME','CTYNAME'])
df_50.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015
# STNAME  CTYNAME
# Alabama Autauga County         623         600
#         Baldwin County        2186        2240
#         Barbour County         260         269
#         Bibb County            247         253
#         Blount County          618         603

# %%
# Must follow the order to query
df_50.loc['Michigan','Washtenaw County']
# Out:
# BIRTHS2010     977
# BIRTHS2011    3826
# BIRTHS2012    3780
# BIRTHS2013    3662
# BIRTHS2014    3683
# BIRTHS2015    3709
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
df_50.loc[[('Michigan','Washtenaw County'),
         ('Michigan','Wayne County')]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709
#          Wayne County           23607       23586

# %%
df_50.T.head()
# Out:
# STNAME            Alabama                                            \
# CTYNAME    Autauga County Baldwin County Barbour County Bibb County
# BIRTHS2010            151            517             70          44
# BIRTHS2011            636           2187            335         266
# BIRTHS2012            615           2092            300         245
# BIRTHS2013            574           2160            283         259
# BIRTHS2014            623           2186            260         247
#
# STNAME                                                                \
# CTYNAME    Blount County Bullock County Butler County Calhoun County
# BIRTHS2010           183             39            65            317
# BIRTHS2011           744            169           276           1382
# BIRTHS2012           710            122           241           1357
# BIRTHS2013           646            132           240           1309
# BIRTHS2014           618            118           267           1355
#
# ...

# %% [markdown]
# ## Missing Values

# %%
df = pd.read_csv('datasets/class_grades.csv')
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00       NaN  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
mask = df.isnull()
mask.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False
# 5   False       False     False    False     False  False
# 6   False       False     False    False     False  False
# 7   False       False     False    False      True  False
# 8   False       False     False    False     False  False
# 9   False       False     False    False     False  False

# %%
df.dropna().head(10)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# 8        8       84.26     93.10    47.50     18.52  50.83
# 9        7       90.10     97.55    51.25     88.89  63.61
# 10       7       80.44     90.20    75.00     91.48  39.72
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22

# %% [markdown]
# ### `df.fillna()`

# %%
df.fillna(0).head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00      0.00  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df = pd.read_csv("datasets/log.csv")
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %% [markdown]
# ### Fill the missing value
# * `ffill`: forward filling
# * `bfill`: backward filling

# %%
df = df.set_index('time')
df = df.sort_index()
df.head(10)
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN

# %%
df = df.reset_index()
df = df.set_index(['time','user'])

# %%
df.head()
# Out:
#                    index          video  playback position paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5  False    10.0
#            sue         1  advanced.html                 23  False    10.0
# 1469974454 cheryl      2     intro.html                  6    NaN     NaN
#            sue         3  advanced.html                 24    NaN     NaN
# 1469974484 cheryl      4     intro.html                  7    NaN     NaN

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                    index          video  playback position  paused  volume
# time       user
# 1469974424 cheryl      0     intro.html                  5   False    10.0
#            sue         1  advanced.html                 23   False    10.0
# 1469974454 cheryl      2     intro.html                  6   False    10.0
#            sue         3  advanced.html                 24   False    10.0
# 1469974484 cheryl      4     intro.html                  7   False    10.0

# %% [markdown]
# ### `replace`

# %%
df = pd.DataFrame({'A':[1,1,2,3,4],
                   'B':[3,6,3,8,9],
                   'C':['a','b','c','d','e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1,100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace([1,3],[100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
df = pd.read_csv("datasets/log.csv")
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
df.replace(to_replace='.*.html$',value='WebPage',regex=True)
# Out:
#           time    user    video  playback position paused  volume
# 0   1469974424  cheryl  WebPage                  5  False    10.0
# 1   1469974454  cheryl  WebPage                  6    NaN     NaN
# 2   1469974544  cheryl  WebPage                  9    NaN     NaN
# 3   1469974574  cheryl  WebPage                 10    NaN     NaN
# 4   1469977514     bob  WebPage                  1    NaN     NaN
# 5   1469977544     bob  WebPage                  1    NaN     NaN
# 6   1469977574     bob  WebPage                  1    NaN     NaN
# 7   1469977604     bob  WebPage                  1    NaN     NaN
# 8   1469974604  cheryl  WebPage                 11    NaN     NaN
# 9   1469974694  cheryl  WebPage                 14    NaN     NaN
# 10  1469974724  cheryl  WebPage                 15    NaN     NaN
# 11  1469974454     sue  WebPage                 24    NaN     NaN
# 12  1469974524     sue  WebPage                 25    NaN     NaN
# ...

# %% [markdown]
# ## Example: Manipulating DataFrame

# %%
df = pd.read_csv('datasets/presidents.csv')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
df['First'] = df['President']
df['First'] = df['First'].replace("[ ].*","",regex = True)
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First
# 0  67 years, 295 days  George
# 1  90 years, 247 days    John
# ...

# %%
del(df['First'])
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
def splitname(row):
    row['First'] = row['President'].split(" ")[0]
    row['Last'] = row['President'].split(" ")[-1]
    return row

df = df.apply(splitname, axis="columns")
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
del(df['First'])
del(df['Last'])

# %%
pattern = "(^[\w]*)(?:.* )([\w]*$)"
df['President'].str.extract(pattern).head()
# Out:
#         0           1
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
pattern = "(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"
names = df['President'].str.extract(pattern).head()
names
# Out:
#     First        Last
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
df['First'] = names['First']
df['Last'] = names['Last']
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# ...

# %%
df["Born"] = df["Born"].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")
df["Born"][:5]
# Out:
# 0    Feb 22, 1732
# 1    Oct 30, 1735
# 2    Apr 13, 1743
# 3    Mar 16, 1751
# 4    Apr 28, 1758
# Name: Born, dtype: object

# %%
df["Born"] = pd.to_datetime(df["Born"])
df["Born"].head()
# Out:
# 0   1732-02-22
# 1   1735-10-30
# 2   1743-04-13
# 3   1751-03-16
# 4   1758-04-28
# Name: Born, dtype: datetime64[ns]

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool
