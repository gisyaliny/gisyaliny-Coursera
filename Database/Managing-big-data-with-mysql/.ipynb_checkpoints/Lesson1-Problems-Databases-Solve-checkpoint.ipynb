# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goals-for-designing-a-database" data-toc-modified-id="Goals-for-designing-a-database-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goals for designing a database</a></span></li><li><span><a href="#Requirements-of-a-well-established-database" data-toc-modified-id="Requirements-of-a-well-established-database-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Requirements of a well-established database</a></span></li></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * SQL only for relational-database

# %% [markdown]
# ## Goals for designing a database
# ![image.png](attachment:image.png)

# %% [markdown]
# * Relational database follows the set theory

# %% [markdown]
# ## Requirements of a well-established database
# ![image.png](attachment:image.png)
