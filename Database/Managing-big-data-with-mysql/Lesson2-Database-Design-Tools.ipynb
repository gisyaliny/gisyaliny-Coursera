# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ER-diagram-(entity-relational-diagram)" data-toc-modified-id="ER-diagram-(entity-relational-diagram)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>ER diagram (entity-relational diagram)</a></span><ul class="toc-item"><li><span><a href="#Box-in-ER-diagram-called-entities" data-toc-modified-id="Box-in-ER-diagram-called-entities-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Box in ER diagram called entities</a></span></li></ul></li><li><span><a href="#Ovals-called-attributes" data-toc-modified-id="Ovals-called-attributes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ovals called attributes</a></span></li><li><span><a href="#Unique-attributes-(unique-among-entities)-also-called-unique-keys-or-unique-identifiers,-Every-entity-must-have-at-least-one-unique-key." data-toc-modified-id="Unique-attributes-(unique-among-entities)-also-called-unique-keys-or-unique-identifiers,-Every-entity-must-have-at-least-one-unique-key.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Unique attributes (unique among entities) also called unique keys or unique identifiers, Every entity must have at least one unique key.</a></span></li><li><span><a href="#Use-diamond-and-lines-to-represent-and-describe-relationships-between-entities." data-toc-modified-id="Use-diamond-and-lines-to-represent-and-describe-relationships-between-entities.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Use diamond and lines to represent and describe relationships between entities.</a></span></li></ul></div>

# %% [markdown]
# ##  ER diagram (entity-relational diagram)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Box in ER diagram called entities
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ovals called attributes
# (according to the set theory, it should be unique, means you could not have two same attributes)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Unique attributes (unique among entities) also called unique keys or unique identifiers, Every entity must have at least one unique key.

# %% [markdown]
# ## Use diamond and lines to represent and describe relationships between entities.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cardinality constraints represent the mapping relationships between different entities (one to many, one to one, many to many)![image.png](attachment:image.png)
